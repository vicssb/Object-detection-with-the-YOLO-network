# %%
pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (8.3.94)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ultralytics) (2.1.1)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ultralytics) (3.10.1)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ultralytics) (1.15.2)
# Requirement already satisfied: torch>=1.8.0 in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ultralytics) (2.6.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ultralytics) (0.21.0)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: py-cpuinfo in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.3.0->ultralytics) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=1.8.0->ultralytics) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=1.8.0->ultralytics) (2025.2.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: colorama in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\vicss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ultralytics import YOLO

# %% [markdown]
# Modelos disponíveis para download na Ultralytics
#
# Também pode ser encontrado aqui: https://docs.ultralytics.com/models/yolov8/#key-features

# %%
from ultralytics.utils.downloads import GITHUB_ASSETS_STEMS
GITHUB_ASSETS_STEMS
# Out:
# ['yolov8n',
#  'yolov8n-cls',
#  'yolov8n-seg',
#  'yolov8n-pose',
#  'yolov8n-obb',
#  'yolov8n-oiv7',
#  'yolov8s',
#  'yolov8s-cls',
#  'yolov8s-seg',
#  'yolov8s-pose',
#  'yolov8s-obb',
#  'yolov8s-oiv7',
#  'yolov8m',
#  'yolov8m-cls',
#  'yolov8m-seg',
#  'yolov8m-pose',
#  'yolov8m-obb',
#  'yolov8m-oiv7',
#  'yolov8l',
#  'yolov8l-cls',
#  'yolov8l-seg',
#  'yolov8l-pose',
#  'yolov8l-obb',
#  'yolov8l-oiv7',
#  'yolov8x',
#  'yolov8x-cls',
#  'yolov8x-seg',
#  'yolov8x-pose',
#  'yolov8x-obb',
#  'yolov8x-oiv7',
#  'yolo11n',
#  'yolo11n-cls',
#  'yolo11n-seg',
#  'yolo11n-pose',
#  'yolo11n-obb',
#  'yolo11s',
#  'yolo11s-cls',
#  'yolo11s-seg',
#  'yolo11s-pose',
#  'yolo11s-obb',
#  'yolo11m',
#  'yolo11m-cls',
#  'yolo11m-seg',
#  'yolo11m-pose',
#  'yolo11m-obb',
#  'yolo11l',
#  'yolo11l-cls',
#  'yolo11l-seg',
#  'yolo11l-pose',
#  'yolo11l-obb',
#  'yolo11x',
#  'yolo11x-cls',
#  'yolo11x-seg',
#  'yolo11x-pose',
#  'yolo11x-obb',
#  'yolo12n',
#  'yolo12s',
#  'yolo12m',
#  'yolo12l',
#  'yolo12x',
#  'yolov5nu',
#  'yolov5n6u',
#  'yolov5su',
#  'yolov5s6u',
#  'yolov5mu',
#  'yolov5m6u',
#  'yolov5lu',
#  'yolov5l6u',
#  'yolov5xu',
#  'yolov5x6u',
#  'yolov3u',
#  'yolov3-sppu',
#  'yolov3-tinyu',
#  'yolov8s-world',
#  'yolov8m-world',
#  'yolov8l-world',
#  'yolov8x-world',
#  'yolov8s-worldv2',
#  'yolov8m-worldv2',
#  'yolov8l-worldv2',
#  'yolov8x-worldv2',
#  'yolov9t',
#  'yolov9s',
#  'yolov9m',
#  'yolov9c',
#  'yolov9e',
#  'yolov10n',
#  'yolov10s',
#  'yolov10m',
#  'yolov10b',
#  'yolov10l',
#  'yolov10x',
#  'yolo_nas_s',
#  'yolo_nas_m',
#  'yolo_nas_l',
#  'sam_b',
#  'sam_l',
#  'FastSAM-s',
#  'FastSAM-x',
#  'rtdetr-l',
#  'rtdetr-x',
#  'mobile_sam',
#  'calibration_image_sample_data_20x128x128x3_float32.npy']

# %% [markdown]
# Configurações padrões do Ultralytics
#
# Também pode ser encontrado aqui: https://docs.ultralytics.com/quickstart/#modifying-settings

# %%
from ultralytics import YOLO, settings
settings
# Out:
# {'settings_version': '0.0.6',
#  'datasets_dir': 'C:\\AI\\Repos machine-learning-specialist-training\\yolov8_vic\\datasets',
#  'weights_dir': 'weights',
#  'runs_dir': './runs',
#  'uuid': '32882eab2791ed3d51379152a8679a0bfd6d3a06afdca7ae0bafb80f40493f3b',
#  'sync': True,
#  'api_key': '',
#  'openai_api_key': '',
#  'clearml': True,
#  'comet': True,
#  'dvc': True,
#  'hub': True,
#  'mlflow': True,
#  'neptune': True,
#  'raytune': True,
#  'tensorboard': True,
#  'wandb': False,
#  'vscode_msg': True}

# %%
settings.update({'runs_dir': './runs'})

# %%
settings
# Out:
# {'settings_version': '0.0.6',
#  'datasets_dir': 'C:\\AI\\Repos machine-learning-specialist-training\\yolov8_vic\\datasets',
#  'weights_dir': 'weights',
#  'runs_dir': './runs',
#  'uuid': '32882eab2791ed3d51379152a8679a0bfd6d3a06afdca7ae0bafb80f40493f3b',
#  'sync': True,
#  'api_key': '',
#  'openai_api_key': '',
#  'clearml': True,
#  'comet': True,
#  'dvc': True,
#  'hub': True,
#  'mlflow': True,
#  'neptune': True,
#  'raytune': True,
#  'tensorboard': True,
#  'wandb': False,
#  'vscode_msg': True}

# %% [markdown]
# ## Treinamento
#
# Todos comandos e instruções: https://docs.ultralytics.com/modes/train/#arguments
#
# Augmentations disponíveis: https://docs.ultralytics.com/usage/cfg/#augmentation

# %%
model = YOLO('yolov8n')  # yolov8n_custom.yaml
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 6.84MB/s]

# %%
model.train(data='custom_dataset.yaml',
            epochs=30,
            patience=8,
            batch=16,  # number of images per batch (-1 for AutoBatch)
            imgsz=640,
            workers=8,
            pretrained=True,
            resume=False,  # resume training from last checkpoint
            single_cls=False,  # Whether all classes will be the same (just one class)
            # project='runs/detect',  # Default = /home/{user}/Documents/ultralytics/runs
            box=7.5,  # More recall, better IoU, less precission, 
            cls=0.5,  # Bbox class better
            dfl=1.5,  # Distribution Focal Loss. Better bbox boundaries
            val=True,
            # Augmentations
            degrees=0.3,
            hsv_s=0.3,
            hsv_v=0.3,
            scale=0.5,
            fliplr=0.5
            )
# Out:
# Ultralytics 8.3.94  Python-3.11.9 torch-2.6.0+cpu CPU (AMD Ryzen 3 3200U with Radeon Vega Mobile Gfx)
# engine\trainer: task=detect, mode=train, model=yolov8n.pt, data=custom_dataset.yaml, epochs=30, time=None, patience=8, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train3, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.3, hsv_v=0.3, degrees=0.3, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs\detect\train3
# Downloading https://ultralytics.com/assets/Arial.ttf to 'C:\Users\vicss\AppData\Roaming\Ultralytics\Arial.ttf'...
# 100%|██████████| 755k/755k [00:00<00:00, 16.1MB/s]
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751897  ultralytics.nn.modules.head.Detect           [3, [64, 128, 256]]
# Model summary: 129 layers, 3,011,433 parameters, 3,011,417 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Scanning C:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\train\labels... 1497 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1497/1497 [00:03<00:00, 460.46it/s]
# train: New cache created: C:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\train\labels.cache
# val: Scanning C:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\valid\labels... 284 images, 0 backgrounds, 0 corrupt: 100%|██████████| 284/284 [00:00<00:00, 575.45it/s]
# val: New cache created: C:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\valid\labels.cache
# Plotting labels to runs\detect\train3\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs\detect\train3
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30         0G      1.354      2.557      1.542         32        640: 100%|██████████| 94/94 [28:06<00:00, 17.94s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 9/9 [01:35<00:00, 10.65s/it]
#                    all        284        348      0.596      0.408       0.47      0.269
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30         0G      1.412      2.094      1.564         22        640: 100%|██████████| 94/94 [24:35<00:00, 15.70s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 9/9 [01:32<00:00, 10.29s/it]
#                    all        284        348       0.32      0.329      0.239      0.118
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/30         0G      1.494      2.023      1.607         32        640: 100%|██████████| 94/94 [25:03<00:00, 15.99s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 9/9 [01
}
# plot: True
# results_dict: {'metrics/precision(B)': np.float64(0.8679988816274697), 'metrics/recall(B)': np.float64(0.8061853351327035), 'metrics/mAP50(B)': np.float64(0.859630283358425), 'metrics/mAP50-95(B)': np.float64(0.6334072425706768), 'fitness': np.float64(0.6560295466494516)}
# save_dir: WindowsPath('runs/detect/train3')
# speed: {'preprocess': 3.661872182880909, 'inference': 216.37023732449012, 'loss': 4.6478817239403725e-05, 'postprocess': 0.6483003520078852}
# task: 'detect'

# %% [markdown]
# ### Reduzir tamanho do checkpoint (somente se não chegou até o fim do treinamento)
#
# ```
# model['epoch'] = -1
# model['best_fitness'] = None
# model['optimizer'] = None
# model['updates'] = None
# model['model'] = model['ema']
# model['ema'] = None
# model.half()
# ```

# %%
#from ultralytics.utils.torch_utils import strip_optimizer
#strip_optimizer('runs/detect/train/weights/best.pt', 'runs/detect/train/weights/best.pt')

# %% [markdown]
# ## Validação e Teste
# Todos comandos e instruções: https://docs.ultralytics.com/modes/val/#arguments

# %%
model = YOLO('runs/detect/train3/weights/best.pt')

# %%
results = model.val(
                    imgsz=640,
                    batch=16,
                    conf=0.001,
                    iou=0.7,  # Non-Maximum Supression (NMS)
                    save_json=False,  # Save to JSON {image_id, cls, bbox, conf} of each image in dataset
                    save_hybrid=False,  # Bounding box labels + inference on the output image (Ultralytics 8.0.178 = results are wrong when this argmunent is True)
                    split='test')  # train, val or test
# Out:
# Ultralytics 8.3.94  Python-3.11.9 torch-2.6.0+cpu CPU (AMD Ryzen 3 3200U with Radeon Vega Mobile Gfx)
# Model summary (fused): 72 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\data\base.py:156, in BaseDataset.get_img_files(self, img_path)
#     155 for p in img_path if isinstance(img_path, list) else [img_path]:
# --> 156     p = Path(p)  # os-agnostic
#     157     if p.is_dir():  # dir
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\pathlib.py:871, in Path.__new__(cls, *args, **kwargs)
#     870     cls = WindowsPath if os.name == 'nt' else PosixPath
# --> 871 self = cls._from_parts(args)
#     872 if not self._flavour.is_supported:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\pathlib.py:509, in PurePath._from_parts(cls, args)
#     508 self = object.__new__(cls)
# --> 509 drv, root, parts = self._parse_args(args)
#     510 self._drv = drv
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\pathlib.py:493, in PurePath._parse_args(cls, args)
#     492 else:
# --> 493     a = os.fspath(a)
#     494     if isinstance(a, str):
#     495         # Force-cast str subclasses to str (issue #21127)
#
# TypeError: expected str, bytes or os.PathLike object, not NoneType
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 results = model.val(
#       2                     imgsz=640,
#       3                     batch=16,
#       4                     conf=0.001,
#       5                     iou=0.7,  # Non-Maximum Supression (NMS)
#       6                     save_json=False,  # Save to JSON {image_id, cls, bbox, conf} of each image in dataset
#       7                     save_hybrid=False,  # Bounding box labels + inference on the output image (Ultralytics 8.0.178 = results are wrong when this argmunent is True)
#       8                     split='test')  # train, val or test
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\engine\model.py:628, in Model.val(self, validator, **kwargs)
#     625 args = {**self.overrides, **custom, **kwargs, "mode": "val"}  # highest priority args on the right
#     627 validator = (validator or self._smart_load("validator"))(args=args, _callbacks=self.callbacks)
# --> 628 validator(model=self.model)
#     629 self.metrics = validator.metrics
#     630 return validator.metrics
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\engine\validator.py:190, in BaseValidator.__call__(self, trainer, model)
#     188     self.args.rect = False
#     189 self.stride = model.stride  # used in get_dataloader() for padding
# --> 190 self.dataloader = self.dataloader or self.get_dataloader(self.data.get(self.args.split), self.args.batch)
#     192 model.eval()
#     193 model.warmup(imgsz=(1 if pt else self.args.batch, 3, imgsz, imgsz))  # warmup
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\models\yolo\detect\val.py:333, in DetectionValidator.get_dataloader(self, dataset_path, batch_size)
#     322 def get_dataloader(self, dataset_path, batch_size):
#     323     """
#     324     Construct and return dataloader.
#     325
#    (...)
#     331         (torch.utils.data.DataLoader): Dataloader for validation.
#     332     """
# --> 333     dataset = self.build_dataset(dataset_path, batch=batch_size, mode="val")
#     334     return build_dataloader(dataset, batch_size, self.args.workers, shuffle=False, rank=-1)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\models\yolo\detect\val.py:320, in DetectionValidator.build_dataset(self, img_path, mode, batch)
#     308 def build_dataset(self, img_path, mode="val", batch=None):
#     309     """
#     310     Build YOLO Dataset.
#     311
#    (...)
#     318         (Dataset): YOLO dataset.
#     319     """
# --> 320     return build_yolo_dataset(self.args, img_path, batch, self.data, mode=mode, stride=self.stride)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\data\build.py:109, in build_yolo_dataset(cfg, img_path, batch, data, mode, rect, stride, multi_modal)
#     107 """Build and return a YOLO dataset based on configuration parameters."""
#     108 dataset = YOLOMultiModalDataset if multi_modal else YOLODataset
# --> 109 return dataset(
#     110     img_path=img_path,
#     111     imgsz=cfg.imgsz,
#     112     batch_size=batch,
#     113     augment=mode == "train",  # augmentation
#     114     hyp=cfg,  # TODO: probably add a get_hyps_from_cfg function
#     115     rect=cfg.rect or rect,  # rectangular batches
#     116     cache=cfg.cache or None,
#     117     single_cls=cfg.single_cls or False,
#     118     stride=int(stride),
#     119     pad=0.0 if mode == "train" else 0.5,
#     120     prefix=colorstr(f"{mode}: "),
#     121     task=cfg.task,
#     122     classes=cfg.classes,
#     123     data=data,
#     124     fraction=cfg.fraction if mode == "train" else 1.0,
#     125 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\data\dataset.py:86, in YOLODataset.__init__(self, data, task, *args, **kwargs)
#      84 self.data = data
#      85 assert not (self.use_segments and self.use_keypoints), "Can not use both segments and keypoints."
# ---> 86 super().__init__(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\data\base.py:107, in BaseDataset.__init__(self, img_path, imgsz, cache, augment, hyp, prefix, rect, batch_size, stride, pad, single_cls, classes, fraction)
#     105 self.prefix = prefix
#     106 self.fraction = fraction
# --> 107 self.im_files = self.get_img_files(self.img_path)
#     108 self.labels = self.get_labels()
#     109 self.update_labels(include_class=classes)  # single_cls and include_class
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\data\base.py:172, in BaseDataset.get_img_files(self, img_path)
#     170     assert im_files, f"{self.prefix}No images found in {img_path}. {FORMATS_HELP_MSG}"
#     171 except Exception as e:
# --> 172     raise FileNotFoundError(f"{self.prefix}Error loading data from {img_path}\n{HELP_URL}") from e
#     173 if self.fraction < 1:
#     174     im_files = im_files[: round(len(im_files) * self.fraction)]  # retain a fraction of the dataset
#
# FileNotFoundError: val: Error loading data from None
# See https://docs.ultralytics.com/datasets for dataset formatting guidance.

# %%
results
# Out:
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7fc277239b50>
# fitness: 0.5447678332086553
# keys: ['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)']
# maps: array([    0.59264,     0.44643])
# names: {0: 'cable_tower', 1: 'turbine'}
# plot: True
# results_dict: {'metrics/precision(B)': 0.817488713740395, 'metrics/recall(B)': 0.6830155352865918, 'metrics/mAP50(B)': 0.7718669123265396, 'metrics/mAP50-95(B)': 0.519534602195557, 'fitness': 0.5447678332086553}
# save_dir: PosixPath('runs/detect/val')
# speed: {'preprocess': 0.739130607018104, 'inference': 8.489522567162146, 'loss': 0.00048233912541316106, 'postprocess': 15.344517047588642}

# %%
results.box
# Out:
# ultralytics.utils.metrics.Metric object with attributes:
#
# all_ap: array([[    0.76939,     0.76563,     0.76139,     0.72541,     0.68681,     0.63427,     0.56358,      0.4631,     0.38183,       0.175],
#        [    0.77434,     0.73456,     0.67904,     0.61271,     0.51259,     0.43272,     0.33404,     0.23806,     0.11202,    0.034211]])
# ap: array([    0.59264,     0.44643])
# ap50: array([    0.76939,     0.77434])
# ap_class_index: array([0, 1])
# f1: array([    0.73004,     0.75291])
# map: 0.519534602195557
# map50: 0.7718669123265396
# map75: 0.5334949008710606
# maps: array([    0.59264,     0.44643])
# mp: 0.817488713740395
# mr: 0.6830155352865918
# nc: 2
# p: array([     0.8593,     0.77567])
# r: array([    0.63458,     0.73145])

# %%
results.box.map50
# Out:
# 0.7718669123265396

# %% [markdown]
# ## Inferência
#
# Todos comandos e instruções: https://docs.ultralytics.com/modes/predict/

# %%
model = YOLO('runs/detect/train3/weights/best.pt')

# %% [markdown]
# ### Imagem

# %%
results_img = model.predict(source='data/test/besouros.mp4',  # image or video; single value or a list; URL, PIL (RGB), CV2 (BGR), ...
                        conf=0.25,
                        iou=0.7,  # Non-Maximum Supression (NMS)
                        imgsz=640,
                        show=False,
                        save=True,
                        save_txt=True,  # Save bbox coordenation
                        save_conf=True,  # save_txt must be True
                        save_crop=True,
                        # project='runs/detect',
                        stream=False  # Do inference now (False) or after (True)
                        )
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 246.2ms
# video 1/1 (frame 2/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 231.2ms
# video 1/1 (frame 3/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Beetle, 1 Butterfly, 222.3ms
# video 1/1 (frame 4/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Beetle, 1 Butterfly, 205.0ms
# video 1/1 (frame 5/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 239.0ms
# video 1/1 (frame 6/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 325.1ms
# video 1/1 (frame 7/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 224.8ms
# video 1/1 (frame 8/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 241.9ms
# video 1/1 (frame 9/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 203.2ms
# video 1/1 (frame 10/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 189.5ms
# video 1/1 (frame 11/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 207.1ms
# video 1/1 (frame 12/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 213.7ms
# video 1/1 (frame 13/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 225.5ms
# video 1/1 (frame 14/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 204.8ms
# video 1/1 (frame 15/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 186.0ms
# video 1/1 (frame 16/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 197.9ms
# video 1/1 (frame 17/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 202.7ms
# video 1/1 (frame 18/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 196.3ms
# video 1/1 (frame 19/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 233.0ms
# video 1/1 (frame 20/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 208.7ms
# video 1/1 (frame 21/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 197.3ms
# video 1/1 (frame 22/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 201.4ms
# video 1/1 (frame 23/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 194.1ms
# video 1/1 (frame 24/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 188.6ms
# video 1/1 (frame 25/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 209.5ms
# video 1/1 (frame 26/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 240.6ms
# video 1/1 (frame 27/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 191.5ms
# video 1/1 (frame 28/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 213.9ms
# video 1/1 (frame 29/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 193.3ms
# video 1/1 (frame 30/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 207.0ms
# video 1/1 (frame 31/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 211.4ms
# video 1/1 (frame 32/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 206.2ms
# video 1/1 (frame 33/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 250.2ms
# video 1/1 (frame 34/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 213.0ms
# video 1/1 (frame 35/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 201.6ms
# video 1/1 (frame 36/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 211.9ms
# video 1/1 (frame 37/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 203.3ms
# video 1/1 (frame 38/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 206.6ms
# video 1/1 (frame 39/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 201.8ms
# video 1/1 (frame 40/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly, 290.8ms
# video 1/1 (frame 41/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Butterfly,
1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 2 Beetles, 227.8ms
# video 1/1 (frame 1281/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 2 Beetles, 380.3ms
# video 1/1 (frame 1282/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 2 Beetles, 249.1ms
# video 1/1 (frame 1283/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Beetle, 212.1ms
# video 1/1 (frame 1284/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Beetle, 326.2ms
# video 1/1 (frame 1285/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Beetle, 389.6ms
# video 1/1 (frame 1286/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Beetle, 243.0ms
# video 1/1 (frame 1287/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Beetle, 246.0ms
# video 1/1 (frame 1288/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 3 Beetles, 210.5ms
# video 1/1 (frame 1289/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 3 Beetles, 245.6ms
# video 1/1 (frame 1290/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 3 Beetles, 223.9ms
# video 1/1 (frame 1291/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 3 Beetles, 243.1ms
# video 1/1 (frame 1292/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 3 Beetles, 258.6ms
# video 1/1 (frame 1293/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 3 Beetles, 195.6ms
# video 1/1 (frame 1294/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 4 Beetles, 202.4ms
# video 1/1 (frame 1295/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 3 Beetles, 237.4ms
# video 1/1 (frame 1296/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 3 Beetles, 223.4ms
# video 1/1 (frame 1297/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 3 Beetles, 194.3ms
# video 1/1 (frame 1298/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 3 Beetles, 213.4ms
# video 1/1 (frame 1299/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 2 Beetles, 286.5ms
# video 1/1 (frame 1300/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 2 Beetles, 196.6ms
# video 1/1 (frame 1301/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 2 Beetles, 237.0ms
# video 1/1 (frame 1302/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 2 Beetles, 231.4ms
# video 1/1 (frame 1303/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 3 Beetles, 228.7ms
# video 1/1 (frame 1304/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 3 Beetles, 278.3ms
# video 1/1 (frame 1305/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Beetle, 219.2ms
# video 1/1 (frame 1306/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Beetle, 197.9ms
# video 1/1 (frame 1307/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Beetle, 373.4ms
# video 1/1 (frame 1308/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 1 Beetle, 223.7ms
# video 1/1 (frame 1309/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 2 Beetles, 282.4ms
# video 1/1 (frame 1310/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 2 Beetles, 192.6ms
# video 1/1 (frame 1311/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 2 Beetles, 236.2ms
# video 1/1 (frame 1312/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 2 Beetles, 217.6ms
# video 1/1 (frame 1313/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 3 Beetles, 202.6ms
# video 1/1 (frame 1314/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 3 Beetles, 228.7ms
# video 1/1 (frame 1315/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 3 Beetles, 208.3ms
# video 1/1 (frame 1316/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 3 Beetles, 201.3ms
# video 1/1 (frame 1317/1317) c:\AI\Repos machine-learning-specialist-training\yolov8_vic\data\test\besouros.mp4: 640x384 3 Beetles, 198.0ms
# Speed: 7.2ms preprocess, 228.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs\detect\predict3
# 1501 labels saved to runs\detect\predict3\labels

# %%
results_img
# Out:
# <generator object BasePredictor.stream_inference at 0x000001E4765045E0>

# %% [markdown]
# - boxes == data - boxes deprecated e não deve ser utilizado
# - data: [x1, y1, x2, y2, conf, cls]
# - shape: [qtd_deteções, 6_colunas_valores]
# - id: [id1, id2, ...] - ID dos objetos que estão sendo detectados na tela. Utilizando pelo sistem de tracking quando ativado
# - is_track: Se está sendo utilizado algum sistem de tracking
# - xywh: [x_center, y_center, width, height] - Para ter o valor superior de x precisa realizar o seguinte cálculo: x_center - width/2
# - xywhn: Mesmo que xywh, porém normalizado pelo tamanho original da imagem
# - xyxy: [x1, y1, x2, y2] - Pontor superior esquerda e ponto inferior direito
# - xyxyn: Mesmo que xyxy, porém normalizado pelo tamanho original da imagem

# %%
results_img[0].boxes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 results_img[0].boxes
#
# TypeError: 'generator' object is not subscriptable

# %% [markdown]
# ### Vídeo

# %% [markdown]
# - "Stream=False": realiza inferência no vídeo completo e armazena todos os resultados em uma lista. Quanto maior o vídeo, maior o consumo de memória RAM para armazenar todos os resultados
# - "stream=True": cria um "generator". O que permite executar frame por frame em um loop, podendo inclusive fazer outras operações em tempo real, sem precisar aguardar que todo o vídeo seja processado. Assim como reduzir a utilização de memória RAM, já que os resultados do frame anterior podem ser eliminados.

# %%
# CAUTION: High memory consumption if "stream=False"
results_video = model.predict(source='besouros.mp4',  # image or video; single value or a list; URL, PIL (RGB), CV2 (BGR), ...
                        conf=0.25,
                        iou=0.7,
                        imgsz=640,
                        show=False,
                        save=True,
                        save_txt=False,  # Save bbox coordination
                        save_conf=False,  # save_txt must be True
                        save_crop=False,
                        # project='runs/detect',
                        stream=True  # Do inference now (False) or after (True)
                        )

# %%
results_video
# Out:
# <generator object BasePredictor.stream_inference at 0x000001E471F96F80>

# %% [markdown]
# Permite executar frame por frame em um loop, podendo fazer outras operações em tempo real, sem precisar aguardar que todo o vídeo seja processado. Assim como reduzir a utilização de memória RAM, já que os resultados do frame anterior podem ser eliminados.

# %%
for result in results_video:
    # Do something with results...
    pass
    # boxes = result.boxes  # Boxes object for bbox outputs
    # masks = result.masks  # Masks object for segmentation masks outputs
    # keypoints = result.keypoints  # Keypoints object for pose outputs
    # probs = result.probs  # Probs object for classification outputs
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 for result in results_video:
#       2     # Do something with results...
#       3     pass
#       4     # boxes = result.boxes  # Boxes object for bbox outputs
#       5     # masks = result.masks  # Masks object for segmentation masks outputs
#       6     # keypoints = result.keypoints  # Keypoints object for pose outputs
#       7     # probs = result.probs  # Probs object for classification outputs
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\engine\predictor.py:295, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     291     self.setup_model(model)
#     293 with self._lock:  # for thread-safe inference
#     294     # Setup source every time predict is called
# --> 295     self.setup_source(source if source is not None else self.args.source)
#     297     # Check if save_dir/ label file exists
#     298     if self.args.save or self.args.save_txt:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\engine\predictor.py:255, in BasePredictor.setup_source(self, source)
#     245 self.imgsz = check_imgsz(self.args.imgsz, stride=self.model.stride, min_dim=2)  # check image size
#     246 self.transforms = (
#     247     getattr(
#     248         self.model.model,
#    (...)
#     253     else None
#     254 )
# --> 255 self.dataset = load_inference_source(
#     256     source=source,
#     257     batch=self.args.batch,
#     258     vid_stride=self.args.vid_stride,
#     259     buffer=self.args.stream_buffer,
#     260 )
#     261 self.source_type = self.dataset.source_type
#     262 if not getattr(self, "stream", True) and (
#     263     self.source_type.stream
#     264     or self.source_type.screenshot
#     265     or len(self.dataset) > 1000  # many images
#     266     or any(getattr(self.dataset, "video_flag", [False]))
#     267 ):  # videos
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\data\build.py:253, in load_inference_source(source, batch, vid_stride, buffer)
#     251     dataset = LoadPilAndNumpy(source)
#     252 else:
# --> 253     dataset = LoadImagesAndVideos(source, batch=batch, vid_stride=vid_stride)
#     255 # Attach source types to the dataset
#     256 setattr(dataset, "source_type", source_type)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\data\loaders.py:342, in LoadImagesAndVideos.__init__(self, path, batch, vid_stride)
#     340         files.append(str((parent / p).absolute()))  # files (relative to *.txt file parent)
#     341     else:
# --> 342         raise FileNotFoundError(f"{p} does not exist")
#     344 # Define files as images or videos
#     345 images, videos = [], []
#
# FileNotFoundError: besouros.mp4 does not exist

# %% [markdown]
# ### Crop objetos

# %%
model = YOLO('runs/detect/train3/weights/best.pt')

# %%
from PIL import Image
import numpy as np
import cv2

# %%
img_pil = Image.open('data/test/2.jpeg')
img_pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=259x194>

# %%
results_img_pil = model.predict(source=img_pil,  # image or video; single value or a list; URL, PIL (RGB), CV2 (BGR), ...
                        conf=0.25,
                        iou=0.7,
                        imgsz=640,
                        show=False,
                        save=True,
                        save_txt=True,  # Save bbox coordination
                        save_conf=True,  # save_txt must be True
                        save_crop=True,
                        # project='runs/detect',
                        stream=False  # Do inference now (False) or after (True)
                        )
# Out:
# 0: 480x640 2 Caterpillars, 229.0ms
# Speed: 3.6ms preprocess, 229.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict2
# 1 label saved to runs\detect\predict2\labels

# %%
xyxy = results_img_pil[0].boxes.xyxy.cpu().numpy()
xyxy
# Out:
# array([[     69.814,      36.451,       241.2,      119.54],
#        [     40.931,      35.446,      241.03,      137.45]], dtype=float32)

# %%
# Pillow
img_pil.crop((xyxy[0][0], xyxy[0][1], xyxy[0][2], xyxy[0][3]))
# Out:
# <PIL.Image.Image image mode=RGB size=171x84>

# %%
# Opencv
img_cv = cv2.imread('data/test/2.jpeg')

results_img_cv2 = model.predict(source=img_cv,  # image or video; single value or a list; URL, PIL (RGB), CV2 (BGR), ...
                        conf=0.25,
                        iou=0.7,
                        imgsz=640,
                        show=False,
                        save=False,
                        save_txt=False,  # Save bbox coordination
                        save_conf=False,  # save_txt must be True
                        save_crop=False,
                        # project='runs/detect',
                        stream=False  # Do inference now (False) or after (True)
                        )
# Out:
# 0: 480x640 2 Caterpillars, 226.0ms
# Speed: 4.0ms preprocess, 226.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)

# %%
xyxy = results_img_cv2[0].boxes.xyxy.cpu().numpy().astype(int)
xyxy
# Out:
# array([[ 69,  36, 241, 119],
#        [ 40,  35, 241, 137]])

# %%
img_cv_cropped = img_cv[xyxy[0][1]:xyxy[0][3], xyxy[0][0]:xyxy[0][2]]
Image.fromarray(cv2.cvtColor(img_cv_cropped, cv2.COLOR_BGR2RGB))
# Out:
# <PIL.Image.Image image mode=RGB size=172x83>

# %% [markdown]
# ### Tracking
#
# Todos comandos e instruções: https://docs.ultralytics.com/modes/track/

# %%
results_track = model.track(source='Borboletas voando.mp4',
                            # project='runs/detect',
                            show=False,
                            save=True)
# Out:
# requirements: Ultralytics requirement ['lap>=0.5.12'] not found, attempting AutoUpdate...
# requirements:  AutoUpdate skipped (offline)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\trackers\utils\matching.py:10
#       9 try:
# ---> 10     import lap  # for linear_assignment
#      12     assert lap.__version__  # verify package is not directory
#
# ModuleNotFoundError: No module named 'lap'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 results_track = model.track(source='Borboletas voando.mp4',
#       2                             # project='runs/detect',
#       3                             show=False,
#       4                             save=True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\engine\model.py:588, in Model.track(self, source, stream, persist, **kwargs)
#     559 """
#     560 Conducts object tracking on the specified input source using the registered trackers.
#     561
#    (...)
#     585     - Batch size is set to 1 for tracking in videos.
#     586 """
#     587 if not hasattr(self.predictor, "trackers"):
# --> 588     from ultralytics.trackers import register_tracker
#     590     register_tracker(self, persist)
#     591 kwargs["conf"] = kwargs.get("conf") or 0.1  # ByteTrack-based method needs low confidence predictions as input
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\trackers\__init__.py:3
#       1 # Ultralytics 🚀 AGPL-3.0 License - https://ultralytics.com/license
# ----> 3 from .bot_sort import BOTSORT
#       4 from .byte_tracker import BYTETracker
#       5 from .track import register_tracker
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\trackers\bot_sort.py:8
#       5 import numpy as np
#       7 from .basetrack import TrackState
# ----> 8 from .byte_tracker import BYTETracker, STrack
#       9 from .utils import matching
#      10 from .utils.gmc import GMC
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\trackers\byte_tracker.py:8
#       6 from ..utils.ops import xywh2ltwh
#       7 from .basetrack import BaseTrack, TrackState
# ----> 8 from .utils import matching
#       9 from .utils.kalman_filter import KalmanFilterXYAH
#      12 class STrack(BaseTrack):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\trackers\utils\matching.py:17
#      14     from ultralytics.utils.checks import check_requirements
#      16     check_requirements("lap>=0.5.12")  # https://github.com/gatagat/lap
# ---> 17     import lap
#      20 def linear_assignment(cost_matrix: np.ndarray, thresh: float, use_lap: bool = True) -> tuple:
#      21     """
#      22     Perform linear assignment using either the scipy or lap.lapjv method.
#      23
#    (...)
#      37         >>> matched_indices, unmatched_a, unmatched_b = linear_assignment(cost_matrix, thresh, use_lap=True)
#      38     """
#
# ModuleNotFoundError: No module named 'lap'

# %%
results_track
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[222, 207, 194],
#          [222, 207, 194],
#          [222, 207, 194],
#          ...,
#          [225, 212, 203],
#          [225, 212, 203],
#          [225, 212, 203]],
#
#         [[222, 207, 194],
#          [222, 207, 194],
#          [222, 207, 194],
#          ...,
#          [225, 212, 203],
#          [225, 212, 203],
#          [225, 212, 203]],
#
#         [[222, 207, 194],
#          [222, 207, 194],
#          [222, 207, 194],
#          ...,
#          [225, 212, 203],
#          [225, 212, 203],
#          [225, 212, 203]],
#
#         ...,
#
#         [[ 28,  62,  57],
#          [ 29,  63,  58],
#          [ 35,  69,  64],
#          ...,
#          [ 47,  65,  58],
#          [ 42,  60,  53],
#          [ 43,  61,  54]],
#
#         [[ 25,  59,  54],
#          [ 29,  63,  58],
#          [ 33,  67,  62],
#          ...,
#          [ 44,  62,  55],
#          [ 42,  60,  53],
#          [ 47,  65,  58]],
#
#         [[ 19,  53,  48],
#          [ 21,  55,  50],
#          [ 25,  59,  54],
#          ...,
#          [ 38,  56,  49],
#          [ 38,  56,  49],
#          [ 46,  64,  57]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 1.0571479797363281, 'inference': 2.7594566345214844, 'postprocess': 1.1286735534667969},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[222, 207, 194],
#          [222, 207, 194],
#          [222, 207, 194],
#          ...,
#          [225, 212, 203],
#          [225, 212, 203],
#          [225, 212, 203]],
#
#         [[222, 207, 194],
#          [222, 207, 194],
#          [222, 207, 194],
#          ...,
#          [225, 212, 203],
#          [225, 212, 203],
#          [225, 212, 203]],
#
#         [[222, 207, 194],
#          [222, 207, 194],
#          [222, 207, 194],
#          ...,
#          [225, 212, 203],
#          [225, 212, 203],
#          [225, 212, 203]],
#
#         ...,
#
#         [[ 38,  72,  67],
#          [ 35,  69,  64],
#          [ 29,  63,  58],
#          ...,
#          [ 39,  57,  50],
#          [ 38,  56,  49],
#          [ 30,  48,  41]],
#
#         [[ 39,  73,  68],
#          [ 35,  69,  64],
#          [ 29,  63,  58],
#          ...,
#          [ 47,  65,  58],
#          [ 45,  63,  56],
#          [ 43,  61,  54]],
#
#         [[ 29,  63,  58],
#          [ 29,  63,  58],
#          [ 29,  63,  58],
#          ...,
#          [ 50,  68,  61],
#          [ 51,  69,  62],
#          [ 52,  70,  63]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 1.0828971862792969, 'inference': 2.2614002227783203, 'postprocess': 2.4688243865966797},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[222, 207, 194],
#          [222, 207, 194],
#          [222, 207, 194],
#          ...,
#          [225, 212, 203],
#          [225, 212, 203],
#          [225, 212, 203]],
#
#         [[222, 207, 194],
#          [222, 207, 194],
#          [222, 207, 194],
#          ...,
#          [225, 212, 203],
#          [225, 212, 203],
#          [225, 212, 203]],
#
#         [[222, 207, 194],
#          [222, 207, 194],
#          [222, 207, 194],
#          ...,
#          [225, 212, 203],
#          [225, 212, 203],
#          [225, 212, 203]],
#
#         ...,
#
#         [[ 16,  50,  45],
#          [ 15,  49,  44],
#          [ 12,  46,  41],
#          ...,
#          [ 33,  51,  44],
#          [ 44,  62,  55],
#          [ 57,  75,  68]],
#
#         [[ 28,  62,  57],
#          [ 29,  63,  58],
#          [ 25,  59,  54],
#          ...,
#          [ 39,  57,  50],
#          [ 40,  58,  51],
#          [ 50,  68,  61]],
#
#         [[ 30,  64,  59],
#          [ 32,  66,  61],
#          [ 36,  70,  65],
#          ...,
#          [ 49,  67,  60],
#          [ 39,  57,  50],
#          [ 45,  63,  56]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 1.079559326171875, 'inference': 2.422332763671875, 'postprocess': 0.6804466247558594},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[222, 207, 194],
#          [222, 207, 194],
#          [222, 207, 194],
#          ...,
#          [225, 212, 203],
#          [225, 212, 203],
#          [225, 212, 203]],
#
#         [[222, 207, 194],
#          [222, 207, 194],
#          [222, 207, 194],
#          ...,
#          [225, 212, 203],
#          [225, 212, 203],
#          [225, 212, 203]],
#
#         [[222, 207, 194],
#          [222, 207, 194],
#          [222, 207, 194],
#          ...,
#          [225, 212, 203],
#          [225, 212, 203],
#          [225, 212, 203]],
#
#         ...,
#
#         [[ 15,  49,  44],
#          [ 18,  52,  47],
#          [ 19,  53,  48],
#          ...,
#          [ 49,  67,  60],
#          [ 41,  57,  50],
#          [ 51,  67,  60]],
#
#         [[ 14,  48,  43],
#          [ 19,  53,  48],
#          [ 22,  56,  51],
#          ...,
#          [ 56,  74,  67],
#          [ 48,  64,  57],
#          [ 49,  65,  58]],
#
#         [[ 31,  65,  60],
#          [ 31,  65,  60],
#          [ 31,  65,  60],
#          ...,
#          [ 54,  72,  65],
#          [ 47,  63,  56],
#          [ 47,  63,  56]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 2.023935317993164, 'inference': 2.649068832397461, 'postprocess': 1.012563705444336},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[222, 207, 194],
#          [222, 207, 194],
#          [222, 207, 194],
#          ...,
#          [225, 212, 203],
#          [225, 212, 203],
#          [225, 212, 203]],
#
#         [[222, 207, 194],
#          [222, 207, 194],
#          [222, 207, 194],
#          ...,
#          [225, 212, 203],
#          [225, 212, 203],
#          [225, 212, 203]],
#
#         [[222, 207, 194],
#          [222, 207, 194],
#          [222, 207, 194],
#          ...,
#          [225, 212, 203],
#          [225, 212, 203],
#          [225, 212, 203]],
#
#         ...,
#
#         [[ 24,  58,  53],
#          [ 24,  58,  53],
#          [ 26,  60,  55],
#          ...,
#          [ 46,  59,  53],
#          [ 42,  54,  51],
#          [ 43,  55,  52]],
#
#         [[ 24,  58,  53],
#          [ 25,  59,  54],
#          [ 29,  63,  58],
#          ...,
#          [ 51,  64,  58],
#          [ 37,  49,  46],
#          [ 39,  51,  48]],
#
#         [[ 28,  62,  57],
#          [ 28,  62,  57],
#          [ 30,  64,  59],
#          ...,
#          [ 53,  66,  60],
#          [ 36,  48,  45],
#          [ 37,  49,  46]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 1.4410018920898438, 'inference': 2.660512924194336, 'postprocess': 0.9365081787109375},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[222, 207, 194],
#          [222, 207, 194],
#          [222, 207, 194],
#          ...,
#          [225, 212, 203],
#          [225, 212, 203],
#          [225, 212, 203]],
#
#         [[222, 207, 194],
#          [222, 207, 194],
#          [222, 207, 194],
#          ...,
#          [225, 212, 203],
#          [225, 212, 203],
#          [225, 212, 203]],
#
#         [[222, 207, 194],
#          [222, 207, 194],
#          [222, 207, 194],
#          ...,
#          [225, 212, 203],
#          [225, 212, 203],
#          [225, 212, 203]],
#
#         ...,
#
#         [[ 29,  63,  56],
#          [ 29,  63,  56],
#          [ 30,  64,  57],
#          ...,
#          [ 40,  55,  51],
#          [ 38,  53,  49],
#          [ 40,  55,  51]],
#
#         [[ 29,  63,  56],
#          [ 29,  63,  56],
#          [ 28,  62,  55],
#          ...,
#          [ 39,  54,  50],
#          [ 46,  61,  57],
#          [ 41,  56,  52]],
#
#         [[ 29,  63,  56],
#          [ 29,  63,  56],
#          [ 29,  63,  56],
#          ...,
#          [ 39,  54,  50],
#          [ 48,  63,  59],
#          [ 41,  56,  52]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 1.0027885437011719, 'inference': 2.2287368774414062, 'postprocess': 0.6952285766601562},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[222, 207, 194],
#          [222, 207, 194],
#          [222, 207, 194],
#          ...,
#          [225, 212, 203],
#          [225, 212, 203],
#          [225, 212, 203]],
#
#         [[222, 207, 194],
#          [222, 207, 194],
#          [222, 207, 194],
#          ...,
#          [225, 212, 203],
#          [225, 212, 203],
#          [225, 212, 203]],
#
#         [[222, 207, 194],
#          [222, 207, 194],
#          [222, 207, 194],
#          ...,
#          [225, 212, 203],
#          [225, 212, 203],
#          [225, 212, 203]],
#
#         ...,
#
#         [[ 30,  64,  57],
#          [ 31,  65,  58],
#          [ 32,  66,  59],
#          ...,
#          [ 45,  60,  56],
#          [ 46,  58,  55],
#          [ 44,  56,  53]],
#
#         [[ 29,  63,  56],
#          [ 30,  64,  57],
#          [ 31,  65,  58],
#          ...,
#          [ 41,  56,  52],
#          [ 47,  59,  56],
#          [ 46,  58,  55]],
#
#         [[ 29,  63,  56],
#          [ 28,  62,  55],
#          [ 30,  64,  57],
#          ...,
#          [ 39,  54,  50],
#          [ 48,  60,  57],
#          [ 47,  59,  56]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 1.1181831359863281, 'inference': 2.2385120391845703, 'postprocess': 0.6804466247558594},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[223, 208, 195],
#          [223, 208, 195],
#          [223, 208, 195],
#          ...,
#          [227, 214, 205],
#          [227, 214, 205],
#          [227, 214, 205]],
#
#         [[223, 208, 195],
#          [223, 208, 195],
#          [223, 208, 195],
#          ...,
#          [227, 214, 205],
#          [227, 214, 205],
#          [227, 214, 205]],
#
#         [[223, 208, 195],
#          [223, 208, 195],
#          [223, 208, 195],
#          ...,
#          [227, 214, 205],
#          [227, 214, 205],
#          [227, 214, 205]],
#
#         ...,
#
#         [[ 26,  60,  53],
#          [ 28,  62,  55],
#          [ 29,  63,  56],
#          ...,
#          [ 44,  57,  51],
#          [ 35,  48,  42],
#          [ 35,  48,  42]],
#
#         [[ 30,  64,  57],
#          [ 29,  63,  56],
#          [ 29,  63,  56],
#          ...,
#          [ 44,  57,  51],
#          [ 44,  57,  51],
#          [ 46,  59,  53]],
#
#         [[ 32,  66,  59],
#          [ 31,  65,  58],
#          [ 31,  65,  58],
#          ...,
#          [ 47,  60,  54],
#          [ 48,  61,  55],
#          [ 53,  66,  60]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 1.4772415161132812, 'inference': 2.2323131561279297, 'postprocess': 0.7152557373046875},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[224, 209, 196],
#          [224, 209, 196],
#          [224, 209, 196],
#          ...,
#          [227, 214, 205],
#          [227, 214, 205],
#          [227, 214, 205]],
#
#         [[224, 209, 196],
#          [224, 209, 196],
#          [224, 209, 196],
#          ...,
#          [227, 214, 205],
#          [227, 214, 205],
#          [227, 214, 205]],
#
#         [[224, 209, 196],
#          [224, 209, 196],
#          [224, 209, 196],
#          ...,
#          [227, 214, 205],
#          [227, 214, 205],
#          [227, 214, 205]],
#
#         ...,
#
#         [[ 21,  55,  48],
#          [ 23,  57,  50],
#          [ 19,  53,  46],
#          ...,
#          [ 34,  47,  41],
#          [ 36,  49,  43],
#          [ 37,  50,  44]],
#
#         [[ 26,  60,  53],
#          [ 26,  60,  53],
#          [ 25,  59,  52],
#          ...,
#          [ 41,  54,  48],
#          [ 43,  56,  50],
#          [ 46,  59,  53]],
#
#         [[ 26,  60,  53],
#          [ 26,  60,  53],
#          [ 28,  62,  55],
#          ...,
#          [ 49,  62,  56],
#          [ 49,  62,  56],
#          [ 50,  63,  57]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 2.366781234741211, 'inference': 2.3653507232666016, 'postprocess': 0.8068084716796875},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[224, 209, 196],
#          [224, 209, 196],
#          [224, 209, 196],
#          ...,
#          [227, 214, 205],
#          [227, 214, 205],
#          [227, 214, 205]],
#
#         [[224, 209, 196],
#          [224, 209, 196],
#          [224, 209, 196],
#          ...,
#          [227, 214, 205],
#          [227, 214, 205],
#          [227, 214, 205]],
#
#         [[224, 209, 196],
#          [224, 209, 196],
#          [224, 209, 196],
#          ...,
#          [227, 214, 205],
#          [227, 214, 205],
#          [227, 214, 205]],
#
#         ...,
#
#         [[ 14,  48,  41],
#          [ 19,  53,  46],
#          [ 22,  56,  49],
#          ...,
#          [ 37,  50,  44],
#          [ 41,  53,  50],
#          [ 43,  55,  52]],
#
#         [[ 15,  49,  42],
#          [ 11,  45,  38],
#          [ 12,  46,  39],
#          ...,
#          [ 41,  54,  48],
#          [ 42,  54,  51],
#          [ 39,  51,  48]],
#
#         [[ 21,  55,  48],
#          [ 16,  50,  43],
#          [ 17,  51,  44],
#          ...,
#          [ 49,  62,  56],
#          [ 47,  59,  56],
#          [ 39,  51,  48]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 1.354217529296875, 'inference': 2.5968551635742188, 'postprocess': 0.7948875427246094},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[224, 209, 196],
#          [224, 209, 196],
#          [224, 209, 196],
#          ...,
#          [227, 214, 205],
#          [227, 214, 205],
#          [227, 214, 205]],
#
#         [[224, 209, 196],
#          [224, 209, 196],
#          [224, 209, 196],
#          ...,
#          [227, 214, 205],
#          [227, 214, 205],
#          [227, 214, 205]],
#
#         [[224, 209, 196],
#          [224, 209, 196],
#          [224, 209, 196],
#          ...,
#          [227, 214, 205],
#          [227, 214, 205],
#          [227, 214, 205]],
#
#         ...,
#
#         [[ 21,  55,  48],
#          [ 21,  55,  48],
#          [ 19,  53,  46],
#          ...,
#          [ 40,  58,  51],
#          [ 38,  56,  49],
#          [ 39,  57,  50]],
#
#         [[ 17,  51,  44],
#          [ 18,  52,  45],
#          [ 17,  51,  44],
#          ...,
#          [ 31,  49,  42],
#          [ 36,  54,  47],
#          [ 42,  60,  53]],
#
#         [[ 17,  51,  44],
#          [ 18,  52,  45],
#          [ 16,  50,  43],
#          ...,
#          [ 26,  44,  37],
#          [ 35,  53,  46],
#          [ 42,  60,  53]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 2.2695064544677734, 'inference': 2.588987350463867, 'postprocess': 0.7767677307128906},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[224, 209, 196],
#          [224, 209, 196],
#          [224, 209, 196],
#          ...,
#          [227, 214, 205],
#          [227, 214, 205],
#          [227, 214, 205]],
#
#         [[224, 209, 196],
#          [224, 209, 196],
#          [224, 209, 196],
#          ...,
#          [227, 214, 205],
#          [227, 214, 205],
#          [227, 214, 205]],
#
#         [[224, 209, 196],
#          [224, 209, 196],
#          [224, 209, 196],
#          ...,
#          [227, 214, 205],
#          [227, 214, 205],
#          [227, 214, 205]],
#
#         ...,
#
#         [[ 12,  46,  39],
#          [ 14,  48,  41],
#          [ 22,  56,  49],
#          ...,
#          [ 42,  60,  53],
#          [ 45,  61,  54],
#          [ 45,  61,  54]],
#
#         [[ 16,  50,  43],
#          [ 18,  52,  45],
#          [ 21,  55,  48],
#          ...,
#          [ 43,  61,  54],
#          [ 45,  61,  54],
#          [ 46,  62,  55]],
#
#         [[ 17,  51,  44],
#          [ 23,  57,  50],
#          [ 22,  56,  49],
#          ...,
#          [ 43,  61,  54],
#          [ 45,  61,  54],
#          [ 46,  62,  55]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 3.1464099884033203, 'inference': 2.721548080444336, 'postprocess': 0.7796287536621094},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[225, 210, 197],
#          [225, 210, 197],
#          [225, 210, 197],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 210, 197],
#          [225, 210, 197],
#          [225, 210, 197],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 210, 197],
#          [225, 210, 197],
#          [225, 210, 197],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         ...,
#
#         [[ 13,  50,  40],
#          [ 13,  50,  40],
#          [ 13,  50,  40],
#          ...,
#          [ 45,  65,  60],
#          [ 47,  67,  62],
#          [ 48,  68,  63]],
#
#         [[ 19,  59,  48],
#          [ 19,  59,  48],
#          [ 19,  59,  48],
#          ...,
#          [ 45,  65,  60],
#          [ 48,  68,  63],
#          [ 49,  69,  64]],
#
#         [[ 24,  64,  53],
#          [ 24,  64,  53],
#          [ 24,  64,  53],
#          ...,
#          [ 45,  65,  60],
#          [ 48,  68,  63],
#          [ 47,  67,  62]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 1.901865005493164, 'inference': 2.6743412017822266, 'postprocess': 1.0380744934082031},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[224, 209, 196],
#          [224, 209, 196],
#          [224, 209, 196],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 210, 197],
#          [225, 210, 197],
#          [225, 210, 197],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 210, 197],
#          [225, 210, 197],
#          [225, 210, 197],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         ...,
#
#         [[ 12,  49,  39],
#          [ 26,  63,  53],
#          [ 34,  71,  61],
#          ...,
#          [ 42,  59,  55],
#          [ 37,  52,  48],
#          [ 32,  47,  43]],
#
#         [[ 14,  54,  43],
#          [ 20,  60,  49],
#          [ 27,  67,  56],
#          ...,
#          [ 46,  63,  59],
#          [ 38,  53,  49],
#          [ 32,  47,  43]],
#
#         [[ 22,  62,  51],
#          [ 12,  52,  41],
#          [ 12,  52,  41],
#          ...,
#          [ 49,  66,  62],
#          [ 40,  55,  51],
#          [ 32,  47,  43]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 2.462148666381836, 'inference': 2.9053688049316406, 'postprocess': 1.1730194091796875},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[224, 209, 196],
#          [224, 209, 196],
#          [224, 209, 196],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 210, 197],
#          [225, 210, 197],
#          [225, 210, 197],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 210, 197],
#          [225, 210, 197],
#          [225, 210, 197],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         ...,
#
#         [[ 27,  64,  54],
#          [ 28,  65,  55],
#          [ 26,  63,  53],
#          ...,
#          [ 33,  48,  44],
#          [ 36,  48,  45],
#          [ 36,  48,  45]],
#
#         [[ 29,  69,  58],
#          [ 27,  67,  56],
#          [ 22,  62,  51],
#          ...,
#          [ 31,  46,  42],
#          [ 33,  45,  42],
#          [ 33,  45,  42]],
#
#         [[ 25,  65,  54],
#          [ 25,  65,  54],
#          [ 21,  61,  50],
#          ...,
#          [ 31,  46,  42],
#          [ 32,  44,  41],
#          [ 30,  42,  39]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 1.65557861328125, 'inference': 2.6917457580566406, 'postprocess': 0.7996559143066406},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[224, 209, 196],
#          [224, 209, 196],
#          [224, 209, 196],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 210, 197],
#          [225, 210, 197],
#          [225, 210, 197],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 210, 197],
#          [225, 210, 197],
#          [225, 210, 197],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         ...,
#
#         [[ 22,  59,  49],
#          [ 29,  66,  56],
#          [ 26,  66,  55],
#          ...,
#          [ 38,  53,  49],
#          [ 40,  55,  51],
#          [ 41,  56,  52]],
#
#         [[ 25,  65,  54],
#          [ 27,  67,  56],
#          [ 27,  67,  56],
#          ...,
#          [ 39,  54,  50],
#          [ 41,  56,  52],
#          [ 41,  56,  52]],
#
#         [[ 27,  67,  56],
#          [ 22,  62,  51],
#          [ 20,  60,  49],
#          ...,
#          [ 39,  54,  50],
#          [ 41,  56,  52],
#          [ 39,  54,  50]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 2.312898635864258, 'inference': 2.632617950439453, 'postprocess': 0.7922649383544922},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[224, 209, 196],
#          [224, 209, 196],
#          [224, 209, 196],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 210, 197],
#          [225, 210, 197],
#          [225, 210, 197],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 210, 197],
#          [225, 210, 197],
#          [225, 210, 197],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         ...,
#
#         [[ 16,  52,  45],
#          [ 19,  55,  48],
#          [ 19,  55,  48],
#          ...,
#          [ 46,  61,  57],
#          [ 48,  63,  59],
#          [ 48,  63,  59]],
#
#         [[ 18,  57,  49],
#          [ 18,  57,  49],
#          [ 15,  54,  46],
#          ...,
#          [ 45,  60,  56],
#          [ 47,  62,  58],
#          [ 45,  60,  56]],
#
#         [[ 18,  57,  49],
#          [ 18,  57,  49],
#          [ 13,  52,  44],
#          ...,
#          [ 44,  59,  55],
#          [ 45,  60,  56],
#          [ 42,  57,  53]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 1.4140605926513672, 'inference': 2.378702163696289, 'postprocess': 1.0128021240234375},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[224, 209, 196],
#          [224, 209, 196],
#          [224, 209, 196],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 210, 197],
#          [225, 210, 197],
#          [225, 210, 197],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 210, 197],
#          [225, 210, 197],
#          [225, 210, 197],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         ...,
#
#         [[ 10,  46,  39],
#          [ 13,  49,  42],
#          [ 22,  58,  53],
#          ...,
#          [ 45,  60,  56],
#          [ 48,  63,  59],
#          [ 52,  67,  63]],
#
#         [[ 10,  49,  41],
#          [ 24,  63,  55],
#          [ 35,  71,  66],
#          ...,
#          [ 40,  55,  51],
#          [ 44,  59,  55],
#          [ 51,  66,  62]],
#
#         [[  8,  47,  39],
#          [ 20,  59,  51],
#          [ 29,  65,  60],
#          ...,
#          [ 34,  49,  45],
#          [ 37,  52,  48],
#          [ 45,  60,  56]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 2.299785614013672, 'inference': 2.6204586029052734, 'postprocess': 0.7350444793701172},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[224, 209, 196],
#          [224, 209, 196],
#          [224, 209, 196],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 210, 197],
#          [225, 210, 197],
#          [225, 210, 197],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 210, 197],
#          [225, 210, 197],
#          [225, 210, 197],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         ...,
#
#         [[ 14,  50,  45],
#          [ 14,  50,  45],
#          [ 21,  57,  50],
#          ...,
#          [ 54,  69,  65],
#          [ 48,  63,  59],
#          [ 42,  57,  53]],
#
#         [[ 26,  62,  57],
#          [ 16,  52,  47],
#          [ 19,  55,  48],
#          ...,
#          [ 49,  64,  60],
#          [ 45,  60,  56],
#          [ 45,  60,  56]],
#
#         [[ 29,  65,  60],
#          [ 21,  57,  52],
#          [ 21,  57,  50],
#          ...,
#          [ 47,  62,  58],
#          [ 44,  59,  55],
#          [ 41,  56,  52]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 2.4366378784179688, 'inference': 2.7310848236083984, 'postprocess': 0.7917881011962891},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[224, 209, 196],
#          [224, 209, 196],
#          [224, 209, 196],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 210, 197],
#          [225, 210, 197],
#          [225, 210, 197],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 210, 197],
#          [225, 210, 197],
#          [225, 210, 197],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         ...,
#
#         [[ 21,  57,  50],
#          [ 19,  55,  48],
#          [ 22,  58,  51],
#          ...,
#          [ 33,  48,  44],
#          [ 42,  54,  51],
#          [ 47,  59,  56]],
#
#         [[ 17,  53,  46],
#          [ 17,  53,  46],
#          [ 24,  60,  53],
#          ...,
#          [ 40,  55,  51],
#          [ 42,  54,  51],
#          [ 43,  55,  52]],
#
#         [[ 27,  63,  56],
#          [ 26,  62,  55],
#          [ 26,  62,  55],
#          ...,
#          [ 44,  59,  55],
#          [ 41,  53,  50],
#          [ 43,  55,  52]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 2.6993751525878906, 'inference': 3.1566619873046875, 'postprocess': 0.7970333099365234},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[224, 209, 196],
#          [224, 209, 196],
#          [224, 209, 196],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 210, 197],
#          [225, 210, 197],
#          [225, 210, 197],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 210, 197],
#          [225, 210, 197],
#          [225, 210, 197],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         ...,
#
#         [[ 24,  58,  51],
#          [ 25,  59,  52],
#          [ 22,  56,  49],
#          ...,
#          [ 42,  54,  51],
#          [ 40,  52,  49],
#          [ 37,  49,  46]],
#
#         [[ 32,  66,  59],
#          [ 33,  67,  60],
#          [ 33,  67,  60],
#          ...,
#          [ 42,  54,  51],
#          [ 41,  53,  50],
#          [ 41,  53,  50]],
#
#         [[ 35,  69,  62],
#          [ 38,  72,  65],
#          [ 40,  74,  67],
#          ...,
#          [ 42,  54,  51],
#          [ 42,  54,  51],
#          [ 42,  54,  51]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 1.6632080078125, 'inference': 2.5758743286132812, 'postprocess': 0.7951259613037109},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[224, 209, 196],
#          [224, 209, 196],
#          [224, 209, 196],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 210, 197],
#          [225, 210, 197],
#          [225, 210, 197],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 210, 197],
#          [225, 210, 197],
#          [225, 210, 197],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         ...,
#
#         [[ 15,  49,  42],
#          [ 12,  46,  39],
#          [ 18,  51,  41],
#          ...,
#          [ 24,  39,  35],
#          [ 32,  47,  43],
#          [ 37,  52,  48]],
#
#         [[ 23,  57,  50],
#          [ 24,  58,  51],
#          [ 26,  59,  49],
#          ...,
#          [ 31,  46,  42],
#          [ 32,  47,  43],
#          [ 34,  49,  45]],
#
#         [[ 36,  70,  63],
#          [ 29,  63,  56],
#          [ 26,  59,  49],
#          ...,
#          [ 37,  52,  48],
#          [ 37,  52,  48],
#          [ 37,  52,  48]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 1.5425682067871094, 'inference': 2.6178359985351562, 'postprocess': 0.7658004760742188},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[225, 210, 197],
#          [225, 210, 197],
#          [225, 210, 197],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 210, 197],
#          [225, 210, 197],
#          [225, 210, 197],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 210, 197],
#          [225, 210, 197],
#          [225, 210, 197],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         ...,
#
#         [[ 21,  54,  44],
#          [ 25,  58,  48],
#          [ 23,  56,  46],
#          ...,
#          [ 27,  42,  38],
#          [ 30,  45,  41],
#          [ 33,  48,  44]],
#
#         [[ 23,  56,  46],
#          [ 23,  56,  46],
#          [ 21,  54,  44],
#          ...,
#          [ 20,  35,  31],
#          [ 27,  42,  38],
#          [ 30,  45,  41]],
#
#         [[ 23,  56,  46],
#          [ 21,  54,  44],
#          [ 23,  56,  46],
#          ...,
#          [ 24,  39,  35],
#          [ 30,  45,  41],
#          [ 31,  46,  42]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 2.2192001342773438, 'inference': 3.503084182739258, 'postprocess': 0.8769035339355469},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[225, 210, 197],
#          [225, 210, 197],
#          [225, 210, 197],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 210, 197],
#          [225, 210, 197],
#          [225, 210, 197],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 210, 197],
#          [225, 210, 197],
#          [225, 210, 197],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         ...,
#
#         [[ 26,  58,  51],
#          [ 30,  62,  55],
#          [ 23,  52,  46],
#          ...,
#          [ 33,  48,  44],
#          [ 41,  53,  50],
#          [ 41,  53,  50]],
#
#         [[ 23,  53,  44],
#          [ 28,  58,  49],
#          [ 21,  51,  42],
#          ...,
#          [ 32,  47,  43],
#          [ 46,  58,  55],
#          [ 43,  55,  52]],
#
#         [[ 26,  56,  47],
#          [ 29,  59,  50],
#          [ 28,  58,  49],
#          ...,
#          [ 31,  46,  42],
#          [ 36,  48,  45],
#          [ 34,  46,  43]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 1.795053482055664, 'inference': 2.688169479370117, 'postprocess': 0.7863044738769531},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[225, 209, 199],
#          [225, 209, 199],
#          [225, 209, 199],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 209, 199],
#          [225, 209, 199],
#          [225, 209, 199],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 209, 199],
#          [225, 209, 199],
#          [225, 209, 199],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         ...,
#
#         [[ 23,  52,  46],
#          [ 25,  54,  48],
#          [ 23,  50,  44],
#          ...,
#          [ 46,  57,  51],
#          [ 41,  52,  46],
#          [ 28,  39,  33]],
#
#         [[ 14,  41,  35],
#          [ 17,  44,  38],
#          [ 16,  43,  37],
#          ...,
#          [ 56,  67,  61],
#          [ 48,  59,  53],
#          [ 32,  43,  37]],
#
#         [[ 15,  42,  36],
#          [ 17,  44,  38],
#          [ 16,  43,  37],
#          ...,
#          [ 51,  62,  56],
#          [ 39,  50,  44],
#          [ 23,  34,  28]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 1.3513565063476562, 'inference': 2.2361278533935547, 'postprocess': 0.6830692291259766},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[225, 209, 199],
#          [225, 209, 199],
#          [225, 209, 199],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 209, 199],
#          [225, 209, 199],
#          [225, 209, 199],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 209, 199],
#          [225, 209, 199],
#          [225, 209, 199],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         ...,
#
#         [[ 19,  48,  42],
#          [ 18,  47,  41],
#          [ 20,  49,  43],
#          ...,
#          [ 30,  41,  35],
#          [ 43,  54,  48],
#          [ 50,  61,  55]],
#
#         [[ 18,  45,  39],
#          [ 17,  44,  38],
#          [ 22,  49,  43],
#          ...,
#          [ 30,  41,  35],
#          [ 42,  53,  47],
#          [ 43,  54,  48]],
#
#         [[ 13,  40,  34],
#          [ 16,  43,  37],
#          [ 27,  54,  48],
#          ...,
#          [ 30,  41,  35],
#          [ 42,  53,  47],
#          [ 37,  48,  42]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 1.4674663543701172, 'inference': 2.9706954956054688, 'postprocess': 0.8208751678466797},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[225, 209, 199],
#          [225, 209, 199],
#          [225, 209, 199],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 209, 199],
#          [225, 209, 199],
#          [225, 209, 199],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 209, 199],
#          [225, 209, 199],
#          [225, 209, 199],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         ...,
#
#         [[ 20,  49,  43],
#          [ 20,  49,  43],
#          [ 30,  59,  53],
#          ...,
#          [ 49,  59,  56],
#          [ 48,  58,  55],
#          [ 46,  56,  53]],
#
#         [[ 28,  55,  49],
#          [ 30,  57,  51],
#          [ 36,  63,  57],
#          ...,
#          [ 45,  55,  52],
#          [ 45,  55,  52],
#          [ 45,  55,  52]],
#
#         [[ 37,  64,  58],
#          [ 41,  68,  62],
#          [ 43,  70,  64],
#          ...,
#          [ 43,  53,  50],
#          [ 42,  52,  49],
#          [ 41,  51,  48]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 2.199888229370117, 'inference': 2.763509750366211, 'postprocess': 0.8177757263183594},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[225, 209, 199],
#          [225, 209, 199],
#          [225, 209, 199],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 209, 199],
#          [225, 209, 199],
#          [225, 209, 199],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 209, 199],
#          [225, 209, 199],
#          [225, 209, 199],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         ...,
#
#         [[ 36,  63,  57],
#          [ 46,  73,  67],
#          [ 59,  83,  78],
#          ...,
#          [ 46,  56,  53],
#          [ 44,  54,  51],
#          [ 42,  52,  49]],
#
#         [[ 47,  71,  66],
#          [ 47,  71,  66],
#          [ 37,  61,  56],
#          ...,
#          [ 44,  54,  51],
#          [ 44,  54,  51],
#          [ 44,  54,  51]],
#
#         [[ 60,  84,  79],
#          [ 50,  74,  69],
#          [ 24,  48,  43],
#          ...,
#          [ 45,  55,  52],
#          [ 48,  58,  55],
#          [ 49,  59,  56]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 1.3790130615234375, 'inference': 2.281665802001953, 'postprocess': 0.9028911590576172},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[225, 209, 199],
#          [225, 209, 199],
#          [225, 209, 199],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 209, 199],
#          [225, 209, 199],
#          [225, 209, 199],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 209, 199],
#          [225, 209, 199],
#          [225, 209, 199],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         ...,
#
#         [[ 48,  72,  67],
#          [ 37,  61,  56],
#          [ 37,  61,  56],
#          ...,
#          [ 43,  53,  50],
#          [ 50,  58,  55],
#          [ 52,  60,  57]],
#
#         [[ 50,  74,  69],
#          [ 41,  65,  60],
#          [ 36,  60,  55],
#          ...,
#          [ 44,  52,  49],
#          [ 45,  53,  50],
#          [ 45,  53,  50]],
#
#         [[ 37,  61,  56],
#          [ 51,  75,  70],
#          [ 45,  69,  64],
#          ...,
#          [ 45,  53,  50],
#          [ 44,  52,  49],
#          [ 40,  48,  45]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 1.7611980438232422, 'inference': 2.6166439056396484, 'postprocess': 0.7841587066650391},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[225, 209, 199],
#          [225, 209, 199],
#          [225, 209, 199],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 209, 199],
#          [225, 209, 199],
#          [225, 209, 199],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 209, 199],
#          [225, 209, 199],
#          [225, 209, 199],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         ...,
#
#         [[ 44,  68,  63],
#          [ 47,  71,  66],
#          [ 51,  75,  70],
#          ...,
#          [ 51,  61,  58],
#          [ 51,  61,  58],
#          [ 51,  61,  58]],
#
#         [[ 51,  75,  70],
#          [ 46,  70,  65],
#          [ 44,  68,  63],
#          ...,
#          [ 44,  54,  51],
#          [ 45,  55,  52],
#          [ 48,  58,  55]],
#
#         [[ 47,  71,  66],
#          [ 41,  65,  60],
#          [ 39,  63,  58],
#          ...,
#          [ 34,  44,  41],
#          [ 34,  44,  41],
#          [ 34,  44,  41]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 2.353668212890625, 'inference': 2.7208328247070312, 'postprocess': 0.7905960083007812},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[225, 209, 199],
#          [225, 209, 199],
#          [225, 209, 199],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 209, 199],
#          [225, 209, 199],
#          [225, 209, 199],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 209, 199],
#          [225, 209, 199],
#          [225, 209, 199],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         ...,
#
#         [[ 55,  82,  76],
#          [ 46,  73,  67],
#          [ 35,  62,  56],
#          ...,
#          [ 49,  59,  56],
#          [ 48,  59,  53],
#          [ 48,  59,  53]],
#
#         [[ 50,  77,  71],
#          [ 44,  71,  65],
#          [ 32,  56,  51],
#          ...,
#          [ 51,  61,  58],
#          [ 51,  62,  56],
#          [ 51,  62,  56]],
#
#         [[ 44,  71,  65],
#          [ 42,  69,  63],
#          [ 29,  53,  48],
#          ...,
#          [ 38,  48,  45],
#          [ 37,  48,  42],
#          [ 36,  47,  41]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 2.534627914428711, 'inference': 3.3011436462402344, 'postprocess': 1.378774642944336},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[225, 209, 199],
#          [225, 209, 199],
#          [225, 209, 199],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 209, 199],
#          [225, 209, 199],
#          [225, 209, 199],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 209, 199],
#          [225, 209, 199],
#          [225, 209, 199],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         ...,
#
#         [[ 41,  68,  62],
#          [ 45,  72,  66],
#          [ 44,  71,  65],
#          ...,
#          [ 36,  45,  39],
#          [ 37,  46,  40],
#          [ 26,  35,  29]],
#
#         [[ 38,  65,  59],
#          [ 44,  71,  65],
#          [ 37,  64,  58],
#          ...,
#          [ 39,  48,  42],
#          [ 31,  40,  34],
#          [ 37,  46,  40]],
#
#         [[ 32,  59,  53],
#          [ 42,  69,  63],
#          [ 37,  64,  58],
#          ...,
#          [ 44,  53,  47],
#          [ 37,  46,  40],
#          [ 44,  53,  47]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 2.204418182373047, 'inference': 2.8481483459472656, 'postprocess': 1.287221908569336},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[225, 209, 199],
#          [225, 209, 199],
#          [225, 209, 199],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 209, 199],
#          [225, 209, 199],
#          [225, 209, 199],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         [[225, 209, 199],
#          [225, 209, 199],
#          [225, 209, 199],
#          ...,
#          [228, 215, 206],
#          [228, 215, 206],
#          [228, 215, 206]],
#
#         ...,
#
# ...
#          ...,
#          [223, 210, 199],
#          [223, 209, 202],
#          [223, 209, 202]],
#
#         [[220, 202, 192],
#          [220, 202, 192],
#          [220, 202, 192],
#          ...,
#          [223, 210, 199],
#          [223, 209, 202],
#          [223, 209, 202]],
#
#         [[220, 202, 192],
#          [220, 202, 192],
#          [220, 202, 192],
#          ...,
#          [223, 210, 199],
#          [223, 209, 202],
#          [223, 209, 202]],
#
#         ...,
#
#         [[ 42,  59,  70],
#          [ 41,  58,  69],
#          [ 41,  58,  69],
#          ...,
#          [ 30,  41,  42],
#          [ 34,  45,  46],
#          [ 37,  48,  49]],
#
#         [[ 43,  60,  71],
#          [ 43,  60,  71],
#          [ 41,  58,  69],
#          ...,
#          [ 32,  43,  44],
#          [ 35,  46,  47],
#          [ 39,  50,  51]],
#
#         [[ 41,  58,  69],
#          [ 43,  60,  71],
#          [ 42,  59,  70],
#          ...,
#          [ 34,  45,  46],
#          [ 39,  50,  51],
#          [ 41,  52,  53]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 1.86920166015625, 'inference': 2.4809837341308594, 'postprocess': 1.4429092407226562},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[222, 202, 192],
#          [222, 202, 192],
#          [222, 202, 192],
#          ...,
#          [223, 210, 199],
#          [223, 209, 202],
#          [223, 209, 202]],
#
#         [[222, 202, 192],
#          [222, 202, 192],
#          [222, 202, 192],
#          ...,
#          [223, 210, 199],
#          [223, 209, 202],
#          [223, 209, 202]],
#
#         [[222, 202, 192],
#          [222, 202, 192],
#          [222, 202, 192],
#          ...,
#          [223, 210, 199],
#          [223, 209, 202],
#          [223, 209, 202]],
#
#         ...,
#
#         [[ 41,  57,  71],
#          [ 46,  62,  76],
#          [ 46,  62,  76],
#          ...,
#          [ 33,  49,  49],
#          [ 41,  55,  55],
#          [ 42,  56,  56]],
#
#         [[ 38,  54,  68],
#          [ 42,  58,  72],
#          [ 42,  58,  72],
#          ...,
#          [ 31,  47,  47],
#          [ 38,  52,  52],
#          [ 37,  51,  51]],
#
#         [[ 36,  52,  66],
#          [ 41,  57,  71],
#          [ 41,  57,  71],
#          ...,
#          [ 35,  51,  51],
#          [ 41,  55,  55],
#          [ 37,  51,  51]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 1.3442039489746094, 'inference': 2.374887466430664, 'postprocess': 0.9005069732666016},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[222, 202, 192],
#          [222, 202, 192],
#          [222, 202, 192],
#          ...,
#          [223, 210, 199],
#          [223, 209, 202],
#          [223, 209, 202]],
#
#         [[222, 202, 192],
#          [222, 202, 192],
#          [222, 202, 192],
#          ...,
#          [223, 210, 199],
#          [223, 209, 202],
#          [223, 209, 202]],
#
#         [[222, 202, 192],
#          [222, 202, 192],
#          [222, 202, 192],
#          ...,
#          [223, 210, 199],
#          [223, 209, 202],
#          [223, 209, 202]],
#
#         ...,
#
#         [[ 47,  63,  77],
#          [ 46,  62,  76],
#          [ 42,  58,  72],
#          ...,
#          [ 45,  59,  59],
#          [ 46,  60,  60],
#          [ 31,  45,  45]],
#
#         [[ 48,  64,  78],
#          [ 46,  62,  76],
#          [ 43,  59,  73],
#          ...,
#          [ 47,  61,  61],
#          [ 47,  61,  61],
#          [ 31,  45,  45]],
#
#         [[ 46,  62,  76],
#          [ 45,  61,  75],
#          [ 43,  59,  73],
#          ...,
#          [ 47,  61,  61],
#          [ 47,  61,  61],
#          [ 31,  45,  45]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 3.36456298828125, 'inference': 2.720355987548828, 'postprocess': 0.8962154388427734},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[222, 202, 192],
#          [222, 202, 192],
#          [222, 202, 192],
#          ...,
#          [223, 210, 199],
#          [223, 209, 202],
#          [223, 209, 202]],
#
#         [[222, 202, 192],
#          [222, 202, 192],
#          [222, 202, 192],
#          ...,
#          [223, 210, 199],
#          [223, 209, 202],
#          [223, 209, 202]],
#
#         [[222, 202, 192],
#          [222, 202, 192],
#          [222, 202, 192],
#          ...,
#          [223, 210, 199],
#          [223, 209, 202],
#          [223, 209, 202]],
#
#         ...,
#
#         [[ 45,  61,  75],
#          [ 43,  59,  73],
#          [ 41,  57,  71],
#          ...,
#          [ 32,  46,  46],
#          [ 34,  45,  46],
#          [ 46,  57,  58]],
#
#         [[ 46,  62,  76],
#          [ 46,  62,  76],
#          [ 43,  59,  73],
#          ...,
#          [ 31,  45,  45],
#          [ 33,  44,  45],
#          [ 46,  57,  58]],
#
#         [[ 48,  64,  78],
#          [ 48,  64,  78],
#          [ 45,  61,  75],
#          ...,
#          [ 31,  45,  45],
#          [ 33,  44,  45],
#          [ 46,  57,  58]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 1.8215179443359375, 'inference': 2.4869441986083984, 'postprocess': 1.1277198791503906},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[222, 202, 192],
#          [222, 202, 192],
#          [222, 202, 192],
#          ...,
#          [223, 210, 199],
#          [223, 209, 202],
#          [223, 209, 202]],
#
#         [[222, 202, 192],
#          [222, 202, 192],
#          [222, 202, 192],
#          ...,
#          [223, 210, 199],
#          [223, 209, 202],
#          [223, 209, 202]],
#
#         [[222, 202, 192],
#          [222, 202, 192],
#          [222, 202, 192],
#          ...,
#          [223, 210, 199],
#          [223, 209, 202],
#          [223, 209, 202]],
#
#         ...,
#
#         [[ 46,  62,  76],
#          [ 46,  62,  76],
#          [ 46,  63,  74],
#          ...,
#          [ 35,  49,  49],
#          [ 48,  62,  62],
#          [ 28,  42,  42]],
#
#         [[ 43,  59,  73],
#          [ 40,  56,  70],
#          [ 39,  56,  67],
#          ...,
#          [ 33,  47,  47],
#          [ 46,  60,  60],
#          [ 31,  45,  45]],
#
#         [[ 43,  59,  73],
#          [ 33,  49,  63],
#          [ 31,  48,  59],
#          ...,
#          [ 25,  39,  39],
#          [ 39,  53,  53],
#          [ 30,  44,  44]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 2.5949478149414062, 'inference': 2.89154052734375, 'postprocess': 1.4705657958984375},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[222, 202, 192],
#          [222, 202, 192],
#          [222, 202, 192],
#          ...,
#          [223, 210, 199],
#          [223, 209, 202],
#          [223, 209, 202]],
#
#         [[222, 202, 192],
#          [222, 202, 192],
#          [222, 202, 192],
#          ...,
#          [223, 210, 199],
#          [223, 209, 202],
#          [223, 209, 202]],
#
#         [[222, 202, 192],
#          [222, 202, 192],
#          [222, 202, 192],
#          ...,
#          [223, 210, 199],
#          [223, 209, 202],
#          [223, 209, 202]],
#
#         ...,
#
#         [[ 35,  52,  63],
#          [ 45,  62,  73],
#          [ 46,  63,  74],
#          ...,
#          [ 33,  47,  47],
#          [ 18,  32,  32],
#          [ 18,  32,  32]],
#
#         [[ 45,  62,  73],
#          [ 43,  60,  71],
#          [ 42,  59,  70],
#          ...,
#          [ 33,  47,  47],
#          [ 18,  32,  32],
#          [ 21,  35,  35]],
#
#         [[ 42,  59,  70],
#          [ 40,  57,  68],
#          [ 41,  58,  69],
#          ...,
#          [ 35,  49,  49],
#          [ 24,  38,  38],
#          [ 26,  40,  40]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 1.462697982788086, 'inference': 2.439737319946289, 'postprocess': 0.8685588836669922},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[222, 202, 192],
#          [222, 202, 192],
#          [222, 202, 192],
#          ...,
#          [223, 210, 199],
#          [223, 209, 202],
#          [223, 209, 202]],
#
#         [[222, 202, 192],
#          [222, 202, 192],
#          [222, 202, 192],
#          ...,
#          [223, 210, 199],
#          [223, 209, 202],
#          [223, 209, 202]],
#
#         [[222, 202, 192],
#          [222, 202, 192],
#          [222, 202, 192],
#          ...,
#          [223, 210, 199],
#          [223, 209, 202],
#          [223, 209, 202]],
#
#         ...,
#
#         [[ 43,  60,  71],
#          [ 42,  59,  70],
#          [ 42,  59,  70],
#          ...,
#          [ 23,  37,  37],
#          [ 23,  35,  34],
#          [ 22,  34,  33]],
#
#         [[ 46,  63,  74],
#          [ 43,  60,  71],
#          [ 42,  59,  70],
#          ...,
#          [ 20,  34,  34],
#          [ 22,  34,  33],
#          [ 22,  34,  33]],
#
#         [[ 42,  59,  70],
#          [ 42,  59,  70],
#          [ 42,  59,  70],
#          ...,
#          [ 20,  34,  34],
#          [ 25,  37,  36],
#          [ 28,  40,  39]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 2.1114349365234375, 'inference': 2.7980804443359375, 'postprocess': 1.6179084777832031},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[219, 204, 191],
#          [219, 204, 191],
#          [219, 204, 191],
#          ...,
#          [223, 210, 201],
#          [223, 208, 204],
#          [223, 208, 204]],
#
#         [[219, 204, 191],
#          [219, 204, 191],
#          [219, 204, 191],
#          ...,
#          [223, 210, 201],
#          [223, 208, 204],
#          [223, 208, 204]],
#
#         [[219, 204, 191],
#          [219, 204, 191],
#          [219, 204, 191],
#          ...,
#          [223, 210, 201],
#          [223, 208, 204],
#          [223, 208, 204]],
#
#         ...,
#
#         [[ 42,  59,  70],
#          [ 42,  59,  70],
#          [ 41,  58,  69],
#          ...,
#          [ 31,  44,  47],
#          [ 33,  46,  49],
#          [ 34,  47,  50]],
#
#         [[ 42,  59,  70],
#          [ 42,  59,  70],
#          [ 41,  58,  69],
#          ...,
#          [ 26,  39,  42],
#          [ 27,  40,  43],
#          [ 30,  43,  46]],
#
#         [[ 42,  59,  70],
#          [ 42,  59,  70],
#          [ 42,  59,  70],
#          ...,
#          [ 24,  37,  40],
#          [ 25,  38,  41],
#          [ 26,  39,  42]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 1.59454345703125, 'inference': 2.877950668334961, 'postprocess': 0.7886886596679688},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[219, 204, 191],
#          [219, 204, 191],
#          [219, 204, 191],
#          ...,
#          [223, 210, 201],
#          [223, 208, 204],
#          [223, 208, 204]],
#
#         [[219, 204, 191],
#          [219, 204, 191],
#          [219, 204, 191],
#          ...,
#          [223, 210, 201],
#          [223, 208, 204],
#          [223, 208, 204]],
#
#         [[219, 204, 191],
#          [219, 204, 191],
#          [219, 204, 191],
#          ...,
#          [223, 210, 201],
#          [223, 208, 204],
#          [223, 208, 204]],
#
#         ...,
#
#         [[ 42,  59,  70],
#          [ 42,  59,  70],
#          [ 42,  59,  70],
#          ...,
#          [ 35,  48,  51],
#          [ 32,  45,  48],
#          [ 27,  40,  43]],
#
#         [[ 42,  59,  70],
#          [ 42,  59,  70],
#          [ 42,  59,  70],
#          ...,
#          [ 32,  45,  48],
#          [ 30,  43,  46],
#          [ 27,  40,  43]],
#
#         [[ 42,  59,  70],
#          [ 42,  59,  70],
#          [ 42,  59,  70],
#          ...,
#          [ 32,  45,  48],
#          [ 30,  43,  46],
#          [ 27,  40,  43]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 2.826690673828125, 'inference': 3.6127567291259766, 'postprocess': 0.8287429809570312},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[219, 204, 191],
#          [219, 204, 191],
#          [219, 204, 191],
#          ...,
#          [223, 210, 201],
#          [223, 208, 204],
#          [223, 208, 204]],
#
#         [[219, 204, 191],
#          [219, 204, 191],
#          [219, 204, 191],
#          ...,
#          [223, 210, 201],
#          [223, 208, 204],
#          [223, 208, 204]],
#
#         [[219, 204, 191],
#          [219, 204, 191],
#          [219, 204, 191],
#          ...,
#          [223, 210, 201],
#          [223, 208, 204],
#          [223, 208, 204]],
#
#         ...,
#
#         [[ 42,  59,  70],
#          [ 42,  59,  70],
#          [ 42,  59,  68],
#          ...,
#          [ 37,  50,  53],
#          [ 28,  41,  44],
#          [ 24,  37,  40]],
#
#         [[ 42,  59,  70],
#          [ 42,  59,  70],
#          [ 43,  60,  69],
#          ...,
#          [ 33,  46,  49],
#          [ 26,  39,  42],
#          [ 21,  34,  37]],
#
#         [[ 42,  59,  70],
#          [ 42,  59,  70],
#          [ 43,  60,  69],
#          ...,
#          [ 30,  43,  46],
#          [ 25,  38,  41],
#          [ 23,  36,  39]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 2.4111270904541016, 'inference': 3.1461715698242188, 'postprocess': 1.3408660888671875},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'cable_tower', 1: 'turbine'}
#  orig_img: array([[[219, 204, 191],
#          [219, 204, 191],
#          [219, 204, 191],
#          ...,
#          [223, 210, 201],
#          [223, 208, 204],
#          [223, 208, 204]],
#
#         [[219, 204, 191],
#          [219, 204, 191],
#          [219, 204, 191],
#          ...,
#          [223, 210, 201],
#          [223, 208, 204],
#          [223, 208, 204]],
#
#         [[219, 204, 191],
#          [219, 204, 191],
#          [219, 204, 191],
#          ...,
#          [223, 210, 201],
#          [223, 208, 204],
#          [223, 208, 204]],
#
#         ...,
#
#         [[ 42,  59,  68],
#          [ 41,  58,  67],
#          [ 42,  59,  68],
#          ...,
#          [ 28,  41,  44],
#          [ 30,  40,  44],
#          [ 30,  40,  44]],
#
#         [[ 43,  60,  69],
#          [ 43,  60,  69],
#          [ 42,  59,  68],
#          ...,
#          [ 25,  38,  41],
#          [ 26,  36,  40],
#          [ 28,  38,  42]],
#
#         [[ 43,  60,  69],
#          [ 43,  60,  69],
#          [ 42,  59,  68],
#          ...,
#          [ 23,  36,  39],
#          [ 23,  33,  37],
#          [ 26,  36,  40]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: '/home/max/Documents/treinar_yolov8/eolico.mp4'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 1.7902851104736328, 'inference': 2.794027328491211, 'postprocess': 1.077890396118164},
#  ...]

# %%
results_track[0].boxes
# Out:
# WARNING ⚠️ 'Boxes.boxes' is deprecated. Use 'Boxes.data' instead.
# ultralytics.engine.results.Boxes object with attributes:
#
# boxes: tensor([[6.6072e+02, 4.3586e+02, 1.0800e+03, 1.1952e+03, 1.0000e+00, 7.3525e-01, 1.0000e+00],
#         [9.4590e+02, 4.5279e+02, 1.0691e+03, 6.3733e+02, 2.0000e+00, 6.6603e-01, 1.0000e+00]])
# cls: tensor([1., 1.])
# conf: tensor([0.7353, 0.6660])
# data: tensor([[6.6072e+02, 4.3586e+02, 1.0800e+03, 1.1952e+03, 1.0000e+00, 7.3525e-01, 1.0000e+00],
#         [9.4590e+02, 4.5279e+02, 1.0691e+03, 6.3733e+02, 2.0000e+00, 6.6603e-01, 1.0000e+00]])
# id: tensor([1., 2.])
# is_track: True
# orig_shape: (1920, 1080)
# shape: torch.Size([2, 7])
# xywh: tensor([[ 870.3604,  815.5455,  419.2792,  759.3657],
#         [1007.4821,  545.0588,  123.1648,  184.5341]])
# xywhn: tensor([[0.8059, 0.4248, 0.3882, 0.3955],
#         [0.9329, 0.2839, 0.1140, 0.0961]])
# xyxy: tensor([[ 660.7208,  435.8627, 1080.0000, 1195.2284],
#         [ 945.8997,  452.7917, 1069.0645,  637.3258]])
# xyxyn: tensor([[0.6118, 0.2270, 1.0000, 0.6225],
#         [0.8758, 0.2358, 0.9899, 0.3319]])
